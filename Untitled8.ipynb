# %%
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17533, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 17533 (delta 16), reused 0 (delta 0), pack-reused 17502 (from 5)
# Receiving objects: 100% (17533/17533), 16.61 MiB | 16.83 MiB/s, done.
# Resolving deltas: 100% (12005/12005), done.
# /content/yolov5
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 52.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 62.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 43.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 14.4 MB/s eta 0:00:00
# ...

# %%
# !python train.py --img 640 --batch 8 --epochs 25 --data /content/data.yaml --weights yolov5s.pt --hyp data/hyps/hyp.scratch-low.yaml --patience 10
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# wandb: WARNING ⚠️ wandb is deprecated and will be removed in a future release. See supported integrations at https://github.com/ultralytics/yolov5#integrations.
# 2025-08-17 04:25:58.075188: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1755404758.443198    2492 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
# !zip -r /content/yolov5_training_output.zip /content/yolov5/runs/train/exp
# Out:
#   adding: content/yolov5/runs/train/exp/ (stored 0%)
#   adding: content/yolov5/runs/train/exp/opt.yaml (deflated 50%)
#   adding: content/yolov5/runs/train/exp/results.csv (deflated 81%)
#   adding: content/yolov5/runs/train/exp/confusion_matrix.png (deflated 40%)
#   adding: content/yolov5/runs/train/exp/F1_curve.png (deflated 21%)
#   adding: content/yolov5/runs/train/exp/val_batch0_pred.jpg (deflated 13%)
#   adding: content/yolov5/runs/train/exp/weights/ (stored 0%)
#   adding: content/yolov5/runs/train/exp/weights/last.pt (deflated 9%)
#   adding: content/yolov5/runs/train/exp/weights/best.pt (deflated 9%)
#   adding: content/yolov5/runs/train/exp/train_batch1.jpg (deflated 8%)
#   adding: content/yolov5/runs/train/exp/train_batch0.jpg (deflated 10%)
#   adding: content/yolov5/runs/train/exp/PR_curve.png (deflated 24%)
#   adding: content/yolov5/runs/train/exp/val_batch0_labels.jpg (deflated 12%)
#   adding: content/yolov5/runs/train/exp/labels_correlogram.jpg (deflated 50%)
# ...

# %%
# !cp /content/yolov5/runs/train/exp/weights/best.pt /content/yolov5/runs/train/exp/weights/best2.pt

# %%
# !zip -r /content/yolov5_training_output.zip /content/yolov5/runs/train/exp
# Out:
# updating: content/yolov5/runs/train/exp/ (stored 0%)
# updating: content/yolov5/runs/train/exp/opt.yaml (deflated 50%)
# updating: content/yolov5/runs/train/exp/results.csv (deflated 81%)
# updating: content/yolov5/runs/train/exp/confusion_matrix.png (deflated 40%)
# updating: content/yolov5/runs/train/exp/F1_curve.png (deflated 21%)
# updating: content/yolov5/runs/train/exp/val_batch0_pred.jpg (deflated 13%)
# updating: content/yolov5/runs/train/exp/weights/ (stored 0%)
# updating: content/yolov5/runs/train/exp/weights/last.pt (deflated 9%)
# updating: content/yolov5/runs/train/exp/weights/best.pt (deflated 9%)
# updating: content/yolov5/runs/train/exp/train_batch1.jpg (deflated 8%)
# updating: content/yolov5/runs/train/exp/train_batch0.jpg (deflated 10%)
# updating: content/yolov5/runs/train/exp/PR_curve.png (deflated 24%)
# updating: content/yolov5/runs/train/exp/val_batch0_labels.jpg (deflated 12%)
# updating: content/yolov5/runs/train/exp/labels_correlogram.jpg (deflated 50%)
# ...

# %%
# !cp /content/yolov5/runs/train/exp/weights/best2.pt /content/best2.pt
